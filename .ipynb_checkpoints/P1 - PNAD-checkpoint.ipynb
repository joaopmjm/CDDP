# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

PNAD2015 = pd.read_csv('PES2015.csv')
PNAD2011 = pd.read_csv('PES2011.csv')

# %% [markdown]
# <i>Projeto 1 - PNAD </i>
#
# João Pedro Montefeltro Junqueira Meirelles
#
# Escolhi fazer minha análise sobre as crianças que estão sujeitas ao trabalho infântil, e relacionar-las com a sua conexão com a tecnologia e observar essa mudança entre os anos de 2011 e 2015, minha principal pergunta é: <b>Como o acesso a tecnologia mudou ou influenciou o trabalho infântil entre os anos de 2011 e 2015</b>
#
# considerarei criança as pessoas de até 11 anos, como se diz no Estatuto da Criança e do Adolescente (ECA). (http://www.planalto.gov.br/Ccivil_03/leis/L8069.htm)

# %%
# Limitando o DataFrame para ter apenas as pessoas menores de 12 anos completos
df_2015 = PNAD2015[PNAD2015.V8005 >= 14]
df_2011 = PNAD2011[PNAD2011.V8005 >= 14]

# %%
# Escolhendo as colunas que irei usar e retirando as que eu não irei e logo depois substituindo os NaNs por 0.0
df_2015 = df_2015[['UF','V8005','V9003','V9004','V9532','V061111','V061112',
                   'V061113','V061114','V061115','V061116','V06112']].copy()
df_2011 = df_2011[['UF','V8005','V9003','V9004','V9532','V06111','V06112',]].copy()
df_2015 = df_2015.fillna(0)
df_2011 = df_2011.fillna(0)

df_2015_limpa = df_2015.copy()

# %%
df_2015.UF = df_2015.UF.astype('category')
df_2015.V9003 = df_2015.V9003.astype('category')
df_2015.V9004 = df_2015.V9004.astype('category')
df_2015.V9532 = df_2015.V9532.astype('category')
df_2015.V061111 = df_2015.V061111.astype('category')
df_2015.V061112 = df_2015.V061112.astype('category')
df_2015.V061113 = df_2015.V061113.astype('category')
df_2015.V061114 = df_2015.V061114.astype('category')
df_2015.V061115 = df_2015.V061115.astype('category')
df_2015.V061116 = df_2015.V061116.astype('category')
df_2015.V06112 = df_2015.V06112.astype('category')

# %%
# Renomeando Variáveis

df_2015_limpa.loc[df_2015_limpa.V9003 == 1, 'V9003'] = 'Exerce'
df_2015_limpa.loc[df_2015_limpa.V9003 == 3, 'V9003'] = 'Não Exerce'
df_2015_limpa.loc[df_2015_limpa.V9003 == 0, 'V9003'] = 'Não se aplica'

df_2015_limpa.loc[df_2015_limpa.V9004 == 2, 'V9004'] = 'Exerce'
df_2015_limpa.loc[df_2015_limpa.V9004 == 4, 'V9004'] = 'Não Exerce'
df_2015_limpa.loc[df_2015_limpa.V9004 == 0, 'V9004'] = 'Não se aplica'

df_2015_limpa.loc[df_2015_limpa.V9532 == 999999999999, 'V9532'] = 'Sem declaração'

df_2015_limpa.loc[df_2015_limpa.V061111 == 1, 'V061111'] = 'Sim'
df_2015_limpa.loc[df_2015_limpa.V061111 == 3, 'V061111'] = 'Não'
df_2015_limpa.loc[df_2015_limpa.V061111 == 0, 'V061111'] = 'Não se aplica'

df_2015_limpa.loc[df_2015_limpa.V061112 == 1, 'V061112'] = 'Sim'
df_2015_limpa.loc[df_2015_limpa.V061112 == 2, 'V061112'] = 'Não'
df_2015_limpa.loc[df_2015_limpa.V061112 == 0, 'V061112'] = 'Não se aplica'

df_2015_limpa.loc[df_2015_limpa.V061113 == 1, 'V061113'] = 'Sim'
df_2015_limpa.loc[df_2015_limpa.V061113 == 2, 'V061113'] = 'Não'
df_2015_limpa.loc[df_2015_limpa.V061113 == 0, 'V061113'] = 'Não se aplica'

df_2015_limpa.loc[df_2015_limpa.V061114 == 1, 'V061114'] = 'Sim'
df_2015_limpa.loc[df_2015_limpa.V061114 == 2, 'V061114'] = 'Não'
df_2015_limpa.loc[df_2015_limpa.V061114 == 0, 'V061114'] = 'Não se aplica'

df_2015_limpa.loc[df_2015_limpa.V061115 == 1, 'V061115'] = 'Sim'
df_2015_limpa.loc[df_2015_limpa.V061115 == 2, 'V061115'] = 'Não'
df_2015_limpa.loc[df_2015_limpa.V061115 == 0, 'V061115'] = 'Não se aplica'

df_2015_limpa.loc[df_2015_limpa.V061116 == 1, 'V061116'] = 'Sim'
df_2015_limpa.loc[df_2015_limpa.V061116 == 2, 'V061116'] = 'Não'
df_2015_limpa.loc[df_2015_limpa.V061116 == 0, 'V061116'] = 'Não se aplica'

df_2015_limpa.loc[df_2015_limpa.V06112 == 1, 'V06112'] = 'Sim'
df_2015_limpa.loc[df_2015_limpa.V06112 == 3, 'V06112'] = 'Não'
df_2015_limpa.loc[df_2015_limpa.V06112 == 0, 'V06112'] = 'Não se aplica'

# %%
df_2015_limpa['UF'][df_2015_limpa.UF == 11] = 'Norte'
df_2015_limpa['UF'][df_2015_limpa.UF == 12] = 'Norte'
df_2015_limpa['UF'][df_2015_limpa.UF == 13] = 'Norte'
df_2015_limpa['UF'][df_2015_limpa.UF == 14] = 'Norte'
df_2015_limpa['UF'][df_2015_limpa.UF == 15] = 'Norte'
df_2015_limpa['UF'][df_2015_limpa.UF == 16] = 'Norte'
df_2015_limpa['UF'][df_2015_limpa.UF == 17] = 'Norte'

df_2015_limpa['UF'][df_2015_limpa.UF == 21] = 'Nordeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 22] = 'Nordeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 23] = 'Nordeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 24] = 'Nordeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 25] = 'Nordeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 26] = 'Nordeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 27] = 'Nordeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 28] = 'Nordeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 29] = 'Nordeste'

df_2015_limpa['UF'][df_2015_limpa.UF == 31] = 'Sudeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 32] = 'Sudeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 33] = 'Sudeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 35] = 'Sudeste'

df_2015_limpa['UF'][df_2015_limpa.UF == 41] = 'Sul'
df_2015_limpa['UF'][df_2015_limpa.UF == 42] = 'Sul'
df_2015_limpa['UF'][df_2015_limpa.UF == 43] = 'Sul'

df_2015_limpa['UF'][df_2015_limpa.UF == 50] = 'Centro_Oeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 51] = 'Centro_Oeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 52] = 'Centro_Oeste'
df_2015_limpa['UF'][df_2015_limpa.UF == 53] = 'Centro_Oeste'
# Out:
# C:\Users\1513 IRON\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2015_limpa = df_2015_limpa.rename(columns={'UF':'Região','V8005':'Idade',
                                              'V9003':'Trabalho Rural',
                                              'V9004':'Trabalho Urbano',
                                              'V9532':'Renda Mensal',
                                              'V061111':'Utilizou Internet',
                                              'V061112':'Computador',
                                              'V061113':'Internet Celular',
                                              'V061114':'Internet Tablet',
                                              'V061115':'Internet TV',
                                              'V061116':'Internet Outro',
                                              'V06112':'Tem Celular'})

# %%
df_2015_limpa
# Out:
#               Região  Idade Trabalho Rural Trabalho Urbano    Renda Mensal  \
# 0              Norte     23  Não se aplica   Não se aplica             800
# 1              Norte     23  Não se aplica   Não se aplica            1150
# 2              Norte     35  Não se aplica   Não se aplica             880
# 3              Norte     34  Não se aplica   Não se aplica            3000
# 7              Norte     18  Não se aplica   Não se aplica             880
# 8              Norte     46  Não se aplica   Não se aplica            3500
# 9              Norte     81     Não Exerce      Não Exerce               0
# 10             Norte     71     Não Exerce      Não Exerce               0
# 11             Norte     47  Não se aplica   Não se aplica             150
# 12             Norte     24     Não Exerce      Não Exerce               0
# 13             Norte     28     Não Exerce      Não Exerce               0
# 14             Norte     50  Não se aplica   Não se aplica            4000
# 16             Norte     34  Não se aplica   Não se aplica             790
# 17             Norte     35  Não se aplica   Não se aplica            2000
# 18             Norte     16  Não se aplica   Não se aplica             930
# 21             Norte     57  Não se aplica   Não se aplica            3150
# 22             Norte     51  Não se aplica   Não se aplica            2000
# 23             Norte     16     Não Exerce      Não Exerce               0
# 24             Norte     60  Não se aplica   Não se aplica            1700
# 25             Norte     50  Não se aplica   Não se aplica            1800
# 26             Norte     30  Não se aplica   Não se aplica            1000
# 27             Norte     26  Não se aplica   Não se aplica            1150
# 28             Norte     20  Não se aplica   Não se aplica             850
# 30             Norte     54     Não Exerce      Não Exerce               0
# 31             Norte     46  Não se aplica   Não se aplica            3000
# 33             Norte     22     Não Exerce      Não Exerce               0
# 35             Norte     49  Não se aplica   Não se aplica            2500
# 36             Norte     45  Não se aplica   Não se aplica            1700
# 37             Norte     55     Não Exerce      Não Exerce               0
# 38             Norte     24  Não se aplica   Não se aplica            2200
# ...              ...    ...            ...             ...             ...
# 356864  Centro_Oeste     88     Não Exerce      Não Exerce               0
# 356865  Centro_Oeste     55     Não Exerce      Não Exerce               0
# 356866  Centro_Oeste     51     Não Exerce      Não Exerce               0
# 356867  Centro_Oeste     47     Não Exerce      Não Exerce               0
# 356868  Centro_Oeste     35  Não se aplica   Não se aplica            1100
# 356869  Centro_Oeste     18     Não Exerce      Não Exerce               0
# 356871  Centro_Oeste     46  Não se aplica   Não se aplica             812
# 356872  Centro_Oeste     21  Não se aplica   Não se aplica  Sem declaração
# 356873  Centro_Oeste     20     Não Exerce      Não Exerce               0
# 356874  Centro_Oeste     15  Não se aplica   Não se aplica             160
# 356875  Centro_Oeste     54     Não Exerce      Não Exerce               0
# 356876  Centro_Oeste     47  Não se aplica   Não se aplica             800
# 356877  Centro_Oeste     24     Não Exerce      Não Exerce               0
# 356878  Centro_Oeste     22     Não Exerce      Não Exerce               0
# 356879  Centro_Oeste     20     Não Exerce      Não Exerce               0
# 356880  Centro_Oeste     28  Não se aplica   Não se aplica             812
# 356881  Centro_Oeste     30  Não se aplica   Não se aplica            1500
# 356882  Centro_Oeste     31     Não Exerce      Não Exerce               0
# 356885  Centro_Oeste     32  Não se aplica   Não se aplica            1300
# 356886  Centro_Oeste     30  Não se aplica   Não se aplica            1100
# 356889  Centro_Oeste     34     Não Exerce      Não Exerce               0
# 356894  Centro_Oeste     57     Não Exerce      Não Exerce               0
# 356895  Centro_Oeste     36  Não se aplica   Não se aplica             800
# 356896  Centro_Oeste     18  Não se aplica   Não se aplica             788
# 356897  Centro_Oeste     57  Não se aplica   Não se aplica            1500
# 356898  Centro_Oeste     33     Não Exerce      Não Exerce               0
# 356899  Centro_Oeste     38  Não se aplica   Não se aplica             900
# 356900  Centro_Oeste     39     Não Exerce      Não Exerce               0
# 356901  Centro_Oeste     17  Não se aplica   Não se aplica             300
# 356902  Centro_Oeste     15     Não Exerce      Não Exerce               0
#
#        Utilizou Internet     Computador Internet Celular Internet Tablet  \
# 0          Não se aplica            Não              Sim             Não
# 1          Não se aplica            Sim              Sim             Não
# 2          Não se aplica            Sim              Sim             Não
# 3          Não se aplica            Sim              Sim             Não
# 7          Não se aplica            Sim              Sim             Não
# 8                    Não  Não se aplica    Não se aplica   Não se aplica
# 9                    Não  Não se aplica    Não se aplica   Não se aplica
# 10         Não se aplica            Sim              Não             Não
# 11                   Não  Não se aplica    Não se aplica   Não se aplica
# 12         Não se aplica            Não              Sim             Não
# 13                   Não  Não se aplica    Não se aplica   Não se aplica
# 14                   Não  Não se aplica    Não se aplica   Não se aplica
# 16         Não se aplica            Sim              Sim             Não
# 17         Não se aplica            Sim              Sim             Não
# 18         Não se aplica            Não              Sim             Não
# 21         Não se aplica            Sim              Sim             Não
# 22         Não se aplica            Sim              Não             Não
# 23         Não se aplica            Sim              Sim             Não
# 24         Não se aplica            Sim              Sim             Não
# 25         Não se aplica            Sim              Sim             Não
# 26         Não se aplica            Sim              Sim             Não
# 27         Não se aplica            Sim              Sim             Não
# 28         Não se aplica            Não              Sim             Não
# 30                   Não  Não se aplica    Não se aplica   Não se aplica
# 31         Não se aplica            Não              Sim             Sim
# 33         Não se aplica            Não              Sim             Sim
# 35                   Não  Não se aplica    Não se aplica   Não se aplica
# 36                   Não  Não se aplica    Não se aplica   Não se aplica
# 37                   Não  Não se aplica    Não se aplica   Não se aplica
# 38         Não se aplica            Sim              Sim             Não
# ...                  ...            ...              ...             ...
# 356864               Não  Não se aplica    Não se aplica   Não se aplica
# 356865               Não  Não se aplica    Não se aplica   Não se aplica
# 356866               Não  Não se aplica    Não se aplica   Não se aplica
# 356867               Não  Não se aplica    Não se aplica   Não se aplica
# 356868     Não se aplica            Não              Sim             Não
# 356869     Não se aplica            Não              Sim             Sim
# 356871               Não  Não se aplica    Não se aplica   Não se aplica
# 356872     Não se aplica            Não              Sim             Não
# 356873     Não se aplica            Não              Sim             Não
# 356874     Não se aplica            Não              Sim             Não
# 356875               Não  Não se aplica    Não se aplica   Não se aplica
# 356876               Não  Não se aplica    Não se aplica   Não se aplica
# 356877     Não se aplica            Não              Sim             Não
# 356878     Não se aplica            Sim              Sim             Não
# 356879     Não se aplica            Sim              Sim             Não
# 356880     Não se aplica            Sim              Sim             Não
# 356881     Não se aplica            Não              Sim             Não
# 356882     Não se aplica            Sim              Sim             Não
# 356885     Não se aplica            Não              Sim             Não
# 356886     Não se aplica            Não              Sim             Não
# 356889     Não se aplica            Sim              Sim             Não
# 356894               Não  Não se aplica    Não se aplica   Não se aplica
# 356895     Não se aplica            Sim              Sim             Não
# 356896     Não se aplica            Sim              Sim             Não
# 356897               Não  Não se aplica    Não se aplica   Não se aplica
# 356898     Não se aplica            Sim              Sim             Não
# 356899     Não se aplica            Sim              Sim             Não
# 356900     Não se aplica            Sim              Sim             Não
# 356901     Não se aplica            Sim              Sim             Não
# 356902     Não se aplica            Sim              Sim             Não
#
#           Internet TV Internet Outro Tem Celular
# 0                 Não            Não         Sim
# 1                 Não            Não         Sim
# 2                 Não            Não         Sim
# 3                 Não            Não         Sim
# 7                 Não            Não         Sim
# 8       Não se aplica  Não se aplica         Sim
# 9       Não se aplica  Não se aplica         Não
# 10                Não            Não         Não
# 11      Não se aplica  Não se aplica         Não
# 12                Não            Não         Sim
# 13      Não se aplica  Não se aplica         Não
# 14      Não se aplica  Não se aplica         Sim
# 16                Não            Não         Sim
# 17                Não            Não         Sim
# 18                Não            Não         Sim
# 21                Não            Não         Sim
# 22                Não            Não         Sim
# 23                Não            Não         Sim
# 24                Não            Não         Sim
# 25                Não            Não         Sim
# 26                Não            Não         Sim
# 27                Não            Não         Sim
# 28                Não            Não         Sim
# 30      Não se aplica  Não se aplica         Sim
# 31                Não            Não         Sim
# 33                Não            Não         Sim
# 35      Não se aplica  Não se aplica         Sim
# 36      Não se aplica  Não se aplica         Sim
# 37      Não se aplica  Não se aplica         Não
# 38                Não            Não         Sim
# ...               ...            ...         ...
# 356864  Não se aplica  Não se aplica         Não
# 356865  Não se aplica  Não se aplica         Não
# 356866  Não se aplica  Não se aplica         Sim
# 356867  Não se aplica  Não se aplica         Não
# 356868            Não            Não         Sim
# 356869            Sim            Não         Sim
# 356871  Não se aplica  Não se aplica         Sim
# 356872            Não            Não         Sim
# 356873            Não            Não         Sim
# 356874            Não            Não         Sim
# 356875  Não se aplica  Não se aplica         Sim
# 356876  Não se aplica  Não se aplica         Sim
# 356877            Não            Não         Sim
# 356878            Não            Não         Sim
# 356879            Não            Não         Sim
# 356880            Não            Não         Sim
# 356881            Não            Não         Sim
# 356882            Não            Não         Sim
# 356885            Não            Não         Sim
# 356886            Não            Não         Sim
# 356889            Não            Não         Sim
# 356894  Não se aplica  Não se aplica         Sim
# 356895            Não            Não         Sim
# 356896            Não            Não         Sim
# 356897  Não se aplica  Não se aplica         Sim
# 356898            Não            Não         Sim
# 356899            Não            Não         Sim
# 356900            Não            Não         Sim
# 356901            Não            Não         Sim
# 356902            Não            Não         Sim
#
# [286462 rows x 12 columns]
